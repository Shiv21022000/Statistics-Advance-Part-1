# %% [markdown]
# #1.What is a random variable in probability theory9

# %% [markdown]
# In probability theory, a random variable is a variable that represents the outcome of a random phenomenon or experiment.

# %% [markdown]
# #2.What are the types of random variables9

# %% [markdown]
# In probability theory, there are mainly two types of random variables, each based on the kind of values they can take:
#
#  1. Discrete Random Variable
# Takes on a finite or countably infinite set of values.
#
# Values are usually whole numbers.
#
# You can list the outcomes.
#
# ✅ Examples:
# Number of students in a class.
#
# Number of heads in 3 coin tosses.
#
# Number of goals scored in a match.
#
#
#  2. Continuous Random Variable
# Takes on an uncountably infinite set of values.
#
# Usually involves measurable quantities like time, weight, or height.
#
# Values lie in a range or interval.
#
# ✅ Examples:
# Temperature in a city during the day.
#
# Time taken to complete a race.
#
# Height of students.

# %% [markdown]
# #3 What is the difference between discrete and continuous distributions9

# %% [markdown]
# The difference between discrete and continuous distributions lies in the type of values the random variable can take and how probabilities are assigned.
#
# 🔍 Difference Between Discrete and Continuous Distributions:
# Feature	Discrete Distribution	Continuous Distribution
# Values Taken	Countable (finite or countably infinite)	Uncountable (any value within a range)
# Examples	0, 1, 2, 3...	2.3, 5.76, 100.123... (real numbers)
# Probability of a Single Value	Can be > 0 (e.g., P(X = 2) = 0.25)	Always 0 (P(X = x) = 0 for any exact value)
# Probability Tool Used	Probability Mass Function (PMF)	Probability Density Function (PDF)
# Graph Type	Bar chart	Smooth curve
# Total Probability	Sum of all probabilities = 1	Area under the curve = 1
#
# 📌 Examples:
# Discrete Distribution:
# Tossing a coin 3 times → outcomes like 0, 1, 2, or 3 heads
#
# Uses Binomial, Poisson, Geometric distributions
#
# Continuous Distribution:
# Measuring weight of a person → any value like 55.4 kg, 55.41 kg
#
# Uses Normal, Exponential, Uniform distributions

# %% [markdown]
# #4. What are probability distribution functions (PDF)9

# %% [markdown]
# In probability theory, a Probability Distribution Function (PDF) describes how the probabilities of a random variable are distributed.
#
# However, the term PDF specifically applies to continuous random variables. For discrete ones, we use Probability Mass Function (PMF).
#
# 🔹 Types of Probability Distribution Functions:
# Type of Variable	Function Used	Description
# Discrete Random Variable	PMF (Probability Mass Function)	Gives the probability P(X = x) for each possible value of X
# Continuous Random Variable	PDF (Probability Density Function)	Describes how dense the probability is around a value; used to calculate probability over intervals
#
# 🔸 1. Probability Mass Function (PMF) – for discrete variables
# Example: Tossing a fair die
#
# 𝑃
# (
# 𝑋
# =
# 3
# )
# =
# 1
# 6
# P(X=3)=
# 6
# 1
# ​
#
# The PMF must satisfy:
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# 𝑖
# )
# ≥
# 0
# P(X=x
# i
# ​
#  )≥0 for all
# 𝑥
# 𝑖
# x
# i
# ​
#
#
# ∑
# 𝑃
# (
# 𝑋
# =
# 𝑥
# 𝑖
# )
# =
# 1
# ∑P(X=x
# i
# ​
#  )=1
#
# 🔸 2. Probability Density Function (PDF) – for continuous variables
# You cannot assign probability to a specific point (e.g.,
# 𝑃
# (
# 𝑋
# =
# 2.0
# )
# =
# 0
# P(X=2.0)=0)
#
# You compute the probability over an interval:
#
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# P(a≤X≤b)=∫
# a
# b
# ​
#  f(x)dx
# The PDF must satisfy:
#
# 𝑓
# (
# 𝑥
# )
# ≥
# 0
# f(x)≥0
#
# Total area under the curve = 1:
#
# ∫
# −
# ∞
# ∞
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# =
# 1
# ∫
# −∞
# ∞
# ​
#  f(x)dx=1
# 📊 Example: Normal Distribution (PDF)
# A bell-shaped curve used to model height, IQ scores, etc. The function is:
#
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 𝜎
# 2
# 𝜋
# 𝑒
# −
# (
# 𝑥
# −
# 𝜇
# )
# 2
# 2
# 𝜎
# 2
# f(x)=
# σ
# 2π
# ​
#
# 1
# ​
#  e
# −
# 2σ
# 2
#
# (x−μ)
# 2
#
# ​
#
#
# where:
#
# 𝜇
# μ = mean
#
# 𝜎
# σ = standard deviation

# %% [markdown]
# #5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)9

# %% [markdown]
# 🔹 PDF vs. CDF: The Difference
# Feature	PDF (Probability Density Function)	CDF (Cumulative Distribution Function)
# Applies to	Continuous random variables (mostly)	Both discrete and continuous variables
# Definition	Describes the density of probability at a point	Describes the accumulated probability up to a point
# Mathematically
# 𝑓
# (
# 𝑥
# )
# f(x) = density function
# 𝐹
# (
# 𝑥
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 𝑥
# )
# F(x)=P(X≤x)
# Usage	Used to find probability over an interval	Used to find probability up to a value
# Probability from it
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# P(a≤X≤b)=∫
# a
# b
# ​
#  f(x)dx
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# =
# 𝐹
# (
# 𝑏
# )
# −
# 𝐹
# (
# 𝑎
# )
# P(a≤X≤b)=F(b)−F(a)
# Graph Shape	Bell-shaped, U-shaped, etc.	Always non-decreasing, S-shaped or step-like
# Value Range	Can be > 1, but area under curve = 1	Always between 0 and 1
#
# 🔸 Example (Continuous):
# Suppose
# 𝑋
# X is a random variable with a normal distribution:
#
# PDF:
# 𝑓
# (
# 𝑥
# )
# f(x) gives the height of the curve at point
# 𝑥
# x
#
# CDF:
# 𝐹
# (
# 𝑥
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 𝑥
# )
# F(x)=P(X≤x) gives the total area under the PDF curve from
# −
# ∞
# −∞ to
# 𝑥
# x
#
# 🔸 Visual Intuition:
# Think of PDF as the speed at each moment.
#
# CDF is the distance traveled up to that moment.

# %% [markdown]
# #6.What is a discrete uniform distribution9

# %% [markdown]
# A discrete uniform distribution is a type of probability distribution where all possible outcomes are equally likely.
#
# 🔹 Definition:
# A discrete uniform distribution assigns equal probability to each of the
# 𝑛
# n values in its finite sample space.
#
# If a random variable
# 𝑋
# X has
# 𝑛
# n equally likely outcomes
# 𝑥
# 1
# ,
# 𝑥
# 2
# ,
# …
# ,
# 𝑥
# 𝑛
# x
# 1
# ​
#  ,x
# 2
# ​
#  ,…,x
# n
# ​
#  , then:
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# 𝑖
# )
# =
# 1
# 𝑛
# for all
# 𝑖
# =
# 1
# ,
# 2
# ,
# …
# ,
# 𝑛
# P(X=x
# i
# ​
#  )=
# n
# 1
# ​
#  for all i=1,2,…,n
# 🔸 Example: Rolling a Fair Die
# Outcomes: {1, 2, 3, 4, 5, 6}
#
# Each outcome has probability:
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 1
# 6
# P(X=x)=
# 6
# 1
# ​
#
# This is a discrete uniform distribution because each number from 1 to 6 is equally likely.
#
# 🔹 Properties:
# Mean (Expected Value):
#
# 𝐸
# (
# 𝑋
# )
# =
# 𝑎
# +
# 𝑏
# 2
# E(X)=
# 2
# a+b
# ​
#
# Variance:
#
# Var
# (
# 𝑋
# )
# =
# (
# 𝑏
# −
# 𝑎
# +
# 1
# )
# 2
# −
# 1
# 12
# Var(X)=
# 12
# (b−a+1)
# 2
#  −1
# ​
#
# where
# 𝑎
# a is the smallest value and
# 𝑏
# b is the largest value.
#
# 🔹 Real-life Examples:
# Drawing a random card from a deck (if suits or ranks only).
#
# Selecting a random student from a list where all have an equal chance.

# %% [markdown]
# #7. What are the key properties of a Bernoulli distribution9

# %% [markdown]
# The Bernoulli distribution is one of the simplest and most fundamental probability distributions in statistics. It models a single trial with only two possible outcomes: success (1) or failure (0).
#
# 🔹 Definition:
# A Bernoulli random variable
# 𝑋
# X takes the value:
#
# 𝑋
# =
# 1
# X=1 with probability
# 𝑝
# p
#
# 𝑋
# =
# 0
# X=0 with probability
# 1
# −
# 𝑝
# 1−p
#
# We write this as:
#
# 𝑋
# ∼
# Bernoulli
# (
# 𝑝
# )
# X∼Bernoulli(p)
# 🔹 Key Properties of Bernoulli Distribution:
# Property	Formula / Description
# Support (Possible Values)
# 𝑋
# ∈
# {
# 0
# ,
# 1
# }
# X∈{0,1}
# Parameter
# 𝑝
# p, the probability of success, where
# 0
# ≤
# 𝑝
# ≤
# 1
# 0≤p≤1
# Mean (Expected Value)
# 𝐸
# (
# 𝑋
# )
# =
# 𝑝
# E(X)=p
# Variance
# Var
# (
# 𝑋
# )
# =
# 𝑝
# (
# 1
# −
# 𝑝
# )
# Var(X)=p(1−p)
# Mode	0 if
# 𝑝
# <
# 0.5
# p<0.5, 1 if
# 𝑝
# >
# 0.5
# p>0.5, both if
# 𝑝
# =
# 0.5
# p=0.5
# Skewness
# 1
# −
# 2
# 𝑝
# 𝑝
# (
# 1
# −
# 𝑝
# )
# p(1−p)
# ​
#
# 1−2p
# ​
#
# Kurtosis
# 1
# −
# 6
# 𝑝
# (
# 1
# −
# 𝑝
# )
# 𝑝
# (
# 1
# −
# 𝑝
# )
# p(1−p)
# 1−6p(1−p)
# ​
#
#
# 🔹 Probability Mass Function (PMF):
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# {
# 𝑝
# if
# 𝑥
# =
# 1
# 1
# −
# 𝑝
# if
# 𝑥
# =
# 0
# P(X=x)={
# p
# 1−p
# ​
#
# if x=1
# if x=0
# ​
#
# Or compactly:
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 𝑝
# 𝑥
# (
# 1
# −
# 𝑝
# )
# 1
# −
# 𝑥
# for
# 𝑥
# ∈
# {
# 0
# ,
# 1
# }
# P(X=x)=p
# x
#  (1−p)
# 1−x
#  for x∈{0,1}
# 🔸 Real-life Examples:
# Flipping a coin (Heads = 1, Tails = 0)
#
# A pass/fail test
#
# Customer buys a product (1) or not (0)
#
# 🔸 Related Distribution:
# Binomial Distribution is the sum of multiple independent Bernoulli trials.

# %% [markdown]
# #8.What is the binomial distribution, and how is it used in probability?

# %% [markdown]
# What is the Binomial Distribution?
# The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes (success or failure) and the same probability of success.
#
# 🔹 Formal Definition:
# If a random variable
# 𝑋
# X follows a binomial distribution, we write:
#
# 𝑋
# ∼
# Bin
# (
# 𝑛
# ,
# 𝑝
# )
# X∼Bin(n,p)
# Where:
#
# 𝑛
# n: number of trials
#
# 𝑝
# p: probability of success in each trial
#
# 𝑋
# X: number of successes in
# 𝑛
# n trials
#
# 🔸 Probability Mass Function (PMF):
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# Where:
#
# 𝑘
# k: number of successes (from 0 to
# 𝑛
# n)
#
# (
# 𝑛
# 𝑘
# )
# (
# k
# n
# ​
#  ): number of ways to choose
# 𝑘
# k successes from
# 𝑛
# n trials
#
# 🔹 Key Properties:
# Property	Formula
# Mean
# 𝐸
# (
# 𝑋
# )
# =
# 𝑛
# 𝑝
# E(X)=np
# Variance
# Var
# (
# 𝑋
# )
# =
# 𝑛
# 𝑝
# (
# 1
# −
# 𝑝
# )
# Var(X)=np(1−p)
# Support
# 𝑋
# ∈
# {
# 0
# ,
# 1
# ,
# 2
# ,
# .
# .
# .
# ,
# 𝑛
# }
# X∈{0,1,2,...,n}
# Mode	Usually
# ⌊
# (
# 𝑛
# +
# 1
# )
# 𝑝
# ⌋
# ⌊(n+1)p⌋ or nearby value(s)
#
# 🔸 Real-Life Examples of Binomial Distribution:
# Flipping a coin 10 times and counting the number of heads.
#
# Number of defective items in a batch of 50 when each item has a 5% defect rate.
#
# Number of students who pass a test out of 20 if each has a 70% chance of passing.

# %% [markdown]
# # 9.What is the Poisson distribution and where is it applied?

# %% [markdown]
# The Poisson distribution is a discrete probability distribution that models the number of times an event occurs in a fixed interval of time, area, volume, or distance, given a constant average rate and independence between events.
#
# 🔹 Formal Definition:
# If a random variable
# 𝑋
# X follows a Poisson distribution with rate
# 𝜆
# λ, we write:
#
# 𝑋
# ∼
# Poisson
# (
# 𝜆
# )
# X∼Poisson(λ)
# Where:
#
# 𝜆
# λ is the average number of events per interval (mean rate)
#
# 𝑋
# X: number of events in the interval
#
# 🔹 Probability Mass Function (PMF):
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝑒
# −
# 𝜆
# 𝜆
# 𝑘
# 𝑘
# !
# P(X=k)=
# k!
# e
# −λ
#  λ
# k
#
# ​
#
# Where:
#
# 𝑘
# =
# 0
# ,
# 1
# ,
# 2
# ,
# …
# k=0,1,2,…
#
# 𝑒
# ≈
# 2.718
# e≈2.718
#
# 𝜆
# >
# 0
# λ>0
#
# 🔹 Key Properties:
# Property	Formula
# Mean
# 𝐸
# (
# 𝑋
# )
# =
# 𝜆
# E(X)=λ
# Variance
# Var
# (
# 𝑋
# )
# =
# 𝜆
# Var(X)=λ
# Support
# 𝑋
# ∈
# {
# 0
# ,
# 1
# ,
# 2
# ,
# …
#
# }
# X∈{0,1,2,…}
#
# 🔸 When to Use the Poisson Distribution:
# Use it when:
#
# Events occur randomly and independently.
#
# You know the average rate
# 𝜆
# λ, but not when the next event will happen.
#
# You're counting the number of events in a fixed interval of time/space.

# %% [markdown]
# #10. What is a continuous uniform distribution

# %% [markdown]
# A continuous uniform distribution is a probability distribution where a continuous random variable is equally likely to take any value within a given interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b].
#
# It’s the continuous counterpart of the discrete uniform distribution

# %% [markdown]
# #11. What are the characteristics of a normal distribution?

# %% [markdown]
# The normal distribution (also called Gaussian distribution) is one of the most important and widely used probability distributions in statistics and data science. It describes continuous data that clusters around a central mean with symmetrical spread.
#
# 🔹 Key Characteristics:
# Feature	Description
# Shape	Symmetrical bell curve
# Mean = Median = Mode	All are equal and located at the center of the distribution
# Symmetry	Perfectly symmetric around the mean
# 𝜇
# μ
# Tails	Extend to
# ±
# ∞
# ±∞, but never touch the horizontal axis
# Total Area Under Curve	Equals 1 (represents total probability)
# Defined by Two Parameters	- Mean (μ): center of the distribution
# - Standard Deviation (σ): spread
# 68-95-99.7 Rule	Also known as the Empirical Rule:
# - ~68% of data within 1σ of mean
# - ~95% within 2σ
# - ~99.7% within 3σ

# %% [markdown]
# #12. What is the standard normal distribution, and why is it important?

# %% [markdown]
# What is the Standard Normal Distribution?
# The standard normal distribution is a special case of the normal distribution with:
#
# Mean
# 𝜇
# =
# 0
# μ=0
#
# Standard deviation
# 𝜎
# =
# 1
# σ=1
#
# We write it as:
#
# 𝑍
# ∼
# 𝑁
# (
# 0
# ,
# 1
# )
# Z∼N(0,1)
# The variable
# 𝑍
# Z is called a standard score or Z-score.
#
# 🔹 Why Is It Important?
# ✅ 1. Simplifies Calculations
#
# Using the standard normal table (Z-table), we can easily find probabilities and percentiles.
#
# All normal distributions can be converted to the standard form using the Z-transformation:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# ✅ 2. Universal Reference
#
# Once converted to Z-scores, any problem involving a normal distribution uses a common reference table, regardless of the original mean or standard deviation.
#
# ✅ 3. Foundation for Hypothesis Testing
#
# Critical values for confidence intervals, p-values, and significance levels are based on the standard normal distribution.
#
# ✅ 4. Central Limit Theorem (CLT)
#
# Thanks to the CLT, the sampling distribution of the sample mean becomes approximately normal for large sample sizes — and often analyzed using standard normal methods.

# %% [markdown]
# #13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?

# %% [markdown]
# The Central Limit Theorem (CLT) is a fundamental concept in statistics that explains why the normal distribution appears so often — even when the underlying data is not normally distributed.
#
# Why Is CLT Critical in Statistics?
# Reason	Explanation
# ✅ Makes inference possible	CLT allows us to apply normal probability methods (Z-scores, confidence intervals, etc.) to non-normal data
# ✅ Supports hypothesis testing	It’s the backbone for tests like t-tests, ANOVA, etc., which assume normally distributed means
# ✅ Foundation of confidence intervals	Lets us calculate how likely it is that a sample mean is near the population mean
# ✅ Works for most distributions	Even if the data is skewed or weird, the sample mean will behave normally (with large
# 𝑛
# n)

# %% [markdown]
# #14. How does the Central Limit Theorem relate to the normal distribution?

# %% [markdown]
# The Central Limit Theorem (CLT) is the reason why the normal distribution is so widely used in statistics — even when the underlying data is not normal.
#
# Relationship Between CLT and Normal Distribution:
# Concept	How They Relate
# CLT	Explains that the distribution of sample means approaches a normal distribution as the sample size increases
# Normal Distribution	Becomes the approximate shape of the sampling distribution of the sample mean (or sum) due to the CLT
# Standard Normal Distribution	Used for calculating probabilities after converting sample means to Z-scores using CLT

# %% [markdown]
# #15. What is the application of Z statistics in hypothesis testing?

# %% [markdown]
# The Z-statistic (or Z-score) is a standardized value used in hypothesis testing to determine how far a sample statistic is from the population parameter under the null hypothesis, measured in standard deviations.
#
# Z-Statistic Formula for Mean:
# 𝑍
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#
# Where:
#
# 𝑋
# ˉ
# X
# ˉ
#   = sample mean
#
# 𝜇
# μ = population mean (under
# 𝐻
# 0
# H
# 0
# ​
#  )
#
# 𝜎
# σ = population standard deviation
#
# 𝑛
# n = sample size
#
# 🔹 Steps in Hypothesis Testing Using Z-Statistics:
# State hypotheses
#
# Null hypothesis
# 𝐻
# 0
# H
# 0
# ​
#  : no effect (e.g.,
# 𝜇
# =
# 100
# μ=100)
#
# Alternative hypothesis
# 𝐻
# 1
# H
# 1
# ​
#  : what you're testing for (e.g.,
# 𝜇
# ≠
# 100
# μ
# 
# =100)
#
# Choose significance level
# 𝛼
# α
#
# Common values: 0.05, 0.01
#
# Calculate Z-statistic
#
# Find critical value or p-value from Z-table
#
# Decision
#
# If
# ∣
# 𝑍
# ∣
# >
# 𝑍
# critical
# ∣Z∣>Z
# critical
# ​
#  , reject
# 𝐻
# 0
# H
# 0
# ​
#
#
# If
# 𝑝
# ≤
# 𝛼
# p≤α, reject
# 𝐻
# 0
# H
# 0
# ​
#
#
# 🔸 Example:
# You believe the average score of a population is 100. You take a sample of 50 students, find an average score of 104, and population standard deviation is 10.
#
# 𝑍
# =
# 104
# −
# 100
# 10
# /
# 50
# ≈
# 4
# 1.41
# ≈
# 2.83
# Z=
# 10/
# 50
# ​
#
# 104−100
# ​
#  ≈
# 1.41
# 4
# ​
#  ≈2.83
# At
# 𝛼
# =
# 0.05
# α=0.05, the critical Z-value for a two-tailed test is ±1.96.
#
# Since
# 2.83
# >
# 1.96
# 2.83>1.96, you reject
# 𝐻
# 0
# H
# 0
# ​
#  .

# %% [markdown]
# #16. How do you calculate a Z-score, and what does it represent?

# %% [markdown]
# A Z-score (also called a standard score) tells you how many standard deviations a data point is from the mean of a distribution.
#
# Z-Score Formula:
# For a single value
# 𝑋
# X:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# Where:
#
# 𝑋
# X: the raw data value
#
# 𝜇
# μ: the population mean
#
# 𝜎
# σ: the population standard deviation
#
#  What the Z-Score Represents:
# Z-score	Interpretation
# 𝑍
# =
# 0
# Z=0	The value is exactly at the mean
# 𝑍
# >
# 0
# Z>0	The value is above the mean
# 𝑍
# <
# 0
# Z<0	The value is below the mean
# 𝑍
# =
# 2
# Z=2	Value is 2 standard deviations above mean
# 𝑍
# =
# −
# 1.5
# Z=−1.5	Value is 1.5 standard deviations below mean

# %% [markdown]
# #17. What are point estimates and interval estimates in statistics?

# %% [markdown]
# In inferential statistics, we often estimate unknown population parameters (like mean or proportion) using sample data. There are two main types of estimates:
#
# 1. Point Estimate
# A point estimate gives a single best guess of a population parameter based on sample data.
#
# ✅ Characteristics:
# It's a single value.
#
# Simple to calculate.
#
# Not very informative about accuracy.
#
# 2. Interval Estimate (Confidence Interval)
# An interval estimate gives a range of values (with a confidence level) within which the population parameter is likely to fall.
#
# ✅ Characteristics:
# More informative than a point estimate
#
# Includes a margin of error
#
# Associated with a confidence level (e.g., 95%)

# %% [markdown]
# #18. What is the significance of confidence intervals in statistical analysis?

# %% [markdown]
# A confidence interval (CI) provides a range of plausible values for an unknown population parameter (like a mean or proportion), based on sample data — along with a degree of certainty.
#
#  Why Confidence Intervals Matter:
# Reason	Explanation
# ✅ Quantifies uncertainty	Instead of just giving a single estimate, a CI shows the margin of error, giving a clearer picture of reliability.
# ✅ Supports decision-making	Helps you understand how precise your estimate is, which is crucial in fields like medicine, business, and engineering.
# ✅ More informative than point estimates	A point estimate gives just a value. A CI tells you how much you can trust it.
# ✅ Used in hypothesis testing	If the null hypothesis value lies outside the CI, you reject it at that confidence level.
# ✅ Interpretability	A 95% CI means: “If we repeated the experiment many times, 95% of those intervals would contain the true population parameter.”
#
#  Final Insight:
# Confidence intervals are essential because they reflect both the estimate and the uncertainty around it — making statistical conclusions more transparent and trustworthy.

# %% [markdown]
# #19. What is the relationship between a Z-score and a confidence interval?

# %% [markdown]
# A Z-score is directly used in calculating a confidence interval (CI) when the population standard deviation
# 𝜎
# σ is known and the sampling distribution is normal.
#
# How They’re Connected:
# The formula for a confidence interval for the population mean (when
# 𝜎
# σ is known) is:
#
# Confidence Interval
# =
# 𝑥
# ˉ
# ±
# 𝑍
# 𝛼
# /
# 2
# ⋅
# 𝜎
# 𝑛
# Confidence Interval=
# x
# ˉ
#  ±Z
# α/2
# ​
#  ⋅
# n
# ​
#
# σ
# ​
#
# Where:
#
# 𝑥
# ˉ
# x
# ˉ
#   = sample mean
#
# 𝜎
# σ = population standard deviation
#
# 𝑛
# n = sample size
#
# 𝑍
# 𝛼
# /
# 2
# Z
# α/2
# ​
#   = Z-score that corresponds to the desired confidence level

# %% [markdown]
# #20. How are Z-scores used to compare different distributions?

# %% [markdown]
# Z-scores (or standard scores) are used to standardize values from different distributions so they can be compared on the same scale, even if the original data sets have different means and standard deviations.
#
#  Z-Score Formula (Recap):
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# Where:
#
# 𝑋
# X = raw score from a distribution
#
# 𝜇
# μ = mean of that distribution
#
# 𝜎
# σ = standard deviation of that distribution
#
#
#
# Why Standardize with Z-Scores?
# Raw values from different distributions can't be compared directly because they:
#
# May have different units (e.g., cm vs. kg)
#
# May have different scales (e.g., scores out of 100 vs. scores out of 800)
#
# 👉 Z-scores transform data to the standard normal distribution, which has:
#
# Mean = 0
#
# Standard deviation = 1

# %% [markdown]
# #21. What are the assumptions for applying the Central Limit Theorem?

# %% [markdown]
# The Central Limit Theorem (CLT) tells us that the sampling distribution of the sample mean approaches a normal distribution, given certain conditions.
#
# But to apply it correctly, some key assumptions must be met:
#
# The CLT is powerful, but it needs clean, well-behaved, and sufficiently large samples to work properly.
#
# Let me know if you'd like a simulation showing how the CLT works under different conditions!

# %% [markdown]
# #22. What is the concept of expected value in a probability distribution/

# %% [markdown]
# The expected value (or mean) of a random variable is a measure of the center of its probability distribution. It tells you the long-run average outcome you would expect if you repeated an experiment many times.
#
# In Simple Terms:
# The expected value is the weighted average of all possible values, where each value is weighted by its probability.
#
# 🔹 1. For Discrete Random Variables:
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# 𝑖
# 𝑥
# 𝑖
# ⋅
# 𝑃
# (
# 𝑥
# 𝑖
# )
# E(X)=
# i
# ∑
# ​
#  x
# i
# ​
#  ⋅P(x
# i
# ​
#  )
# Where:
#
# 𝑥
# 𝑖
# x
# i
# ​
#  : a possible outcome
#
# 𝑃
# (
# 𝑥
# 𝑖
# )
# P(x
# i
# ​
#  ): probability of that outcome
#
# 𝐸
# (
# 𝑋
# )
# E(X): expected value of random variable
# 𝑋
# X
#
# ✅ Example:
# Roll a fair 6-sided die:
#
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# 𝑖
# =
# 1
# 6
# 𝑖
# ⋅
# 1
# 6
# =
# 1
# +
# 2
# +
# 3
# +
# 4
# +
# 5
# +
# 6
# 6
# =
# 3.5
# E(X)=
# i=1
# ∑
# 6
# ​
#  i⋅
# 6
# 1
# ​
#  =
# 6
# 1+2+3+4+5+6
# ​
#  =3.5
# You never roll a 3.5, but over thousands of rolls, your average will approach 3.5.
#
# 🔹 2. For Continuous Random Variables:
# 𝐸
# (
# 𝑋
# )
# =
# ∫
# −
# ∞
# ∞
# 𝑥
# ⋅
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# E(X)=∫
# −∞
# ∞
# ​
#  x⋅f(x)dx
# Where:
#
# 𝑓
# (
# 𝑥
# )
# f(x) is the probability density function (PDF)
#
# 🔹 Key Properties of Expected Value:
# Property	Description
# Linearity
# 𝐸
# (
# 𝑎
# 𝑋
# +
# 𝑏
# )
# =
# 𝑎
# 𝐸
# (
# 𝑋
# )
# +
# 𝑏
# E(aX+b)=aE(X)+b
# Can be negative or fractional	It’s not always a value the variable can actually take
# May not always exist	Only defined when the sum or integral converges

# %% [markdown]
# #23. How does a probability distribution relate to the expected outcome of a random variable?

# %% [markdown]
# The probability distribution describes all possible outcomes of a random variable along with their associated probabilities. The expected outcome (also called the expected value or mean) is a summary measure of that distribution — it represents the long-run average result of repeated trials.
#
# 🔹 Here's the Connection:
# The expected value is calculated directly from the probability distribution — it’s a weighted average of all possible outcomes, using their probabilities as weights.
#
# Mathematically:
# ✅ For a discrete random variable:
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# 𝑖
# 𝑥
# 𝑖
# ⋅
# 𝑃
# (
# 𝑥
# 𝑖
# )
# E(X)=
# i
# ∑
# ​
#  x
# i
# ​
#  ⋅P(x
# i
# ​
#  )
# ✅ For a continuous random variable:
# 𝐸
# (
# 𝑋
# )
# =
# ∫
# −
# ∞
# ∞
# 𝑥
# ⋅
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# E(X)=∫
# −∞
# ∞
# ​
#  x⋅f(x)dx
# Where:
#
# 𝑥
# 𝑖
# x
# i
# ​
#   or
# 𝑥
# x = possible values of the random variable
#
# 𝑃
# (
# 𝑥
# 𝑖
# )
# P(x
# i
# ​
#  ) or
# 𝑓
# (
# 𝑥
# )
# f(x) = probability or probability density
#
# 𝐸
# (
# 𝑋
# )
# E(X) = expected value
#
# 🔸 Example – Discrete Case:
# A game pays:
#
# ₹10 with probability 0.3
#
# ₹20 with probability 0.5
#
# ₹0 with probability 0.2
#
# Expected outcome:
#
# 𝐸
# (
# 𝑋
# )
# =
# 10
# (
# 0.3
# )
# +
# 20
# (
# 0.5
# )
# +
# 0
# (
# 0.2
# )
# =
# 3
# +
# 10
# +
# 0
# =
# ₹
# 13
# E(X)=10(0.3)+20(0.5)+0(0.2)=3+10+0=₹13
# So, the expected outcome is ₹13 — if you played this game many times, you'd average ₹13 per play.
#
# ✅ Summary:
# Concept	Relationship
# Probability distribution	Describes all possible values of a random variable and their likelihood
# Expected value	The average of those values, weighted by their probabilities
#
# In essence:
#
# The expected value is the center of a probability distribution — it's how we summarize the distribution into a single representative number.
